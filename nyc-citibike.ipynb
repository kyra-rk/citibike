# %% [markdown]
# ## Learning pandas by exploring NYC Citibike Data
# Data Source is https://citibikenyc.com/system-data

# %%
import pandas as pd
column_data_types = {5: str, 7: str}
df = pd.read_csv('202305-citibike-tripdata.csv', dtype=column_data_types)
print(df.head())
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  176B188F3289F37B   classic_bike  2023-05-23 19:22:53  2023-05-23 19:35:23
# 1  BB6957A02501C686   classic_bike  2023-05-27 08:49:55  2023-05-27 08:57:42
# 2  C67567E1DAFB9F2C   classic_bike  2023-05-12 20:19:58  2023-05-12 20:36:07
# 3  89DDFCEAE05D043A  electric_bike  2023-05-03 07:59:13  2023-05-03 08:07:04
# 4  63B1D5A7A2316252   classic_bike  2023-05-13 10:23:52  2023-05-13 10:47:17
#
#          start_station_name start_station_id  \
# 0        E 50 St & Park Ave          6659.10
# 1  Flatbush Ave & Ocean Ave          3704.04
# 2  Flatbush Ave & Ocean Ave          3704.04
# 3  Flatbush Ave & Ocean Ave          3704.04
# 4  Flatbush Ave & Ocean Ave          3704.04
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                   E 74 St & 1 Ave        6953.08  40.757306 -73.974518
# 1  Grand Army Plaza & Plaza St West        4010.15  40.663657 -73.963014
# ...

# %% [markdown]
# ## Basic Data Exploration

# %%
# what kinds of rides can users take? 
df['rideable_type'].unique()
# array(['classic_bike', 'electric_bike', 'docked_bike'], dtype=object)
docked_rides = df[df['rideable_type'] == 'docked_bike']
docked_rides
# i have no clue what a "docked bike" is.... what makes it different from electric bike or classic bike?
# Out:
#                   ride_id rideable_type           started_at  \
# 13       A303930EFAAA0441   docked_bike  2023-05-24 16:45:33
# 215      299B6624638C83BA   docked_bike  2023-05-15 09:58:27
# 272      8DB61473D85BB3E1   docked_bike  2023-05-26 12:08:21
# 1298     FD604ADF40FE211C   docked_bike  2023-05-21 15:29:19
# 1299     A1C3B85EAF3C762A   docked_bike  2023-05-21 15:44:49
# ...                   ...           ...                  ...
# 3580229  CF99C7C807F66EB1   docked_bike  2023-05-19 14:56:46
# 3580358  C9F76AA7B3FB5E22   docked_bike  2023-05-22 16:35:06
# 3580485  3C6866AE02958B64   docked_bike  2023-05-19 14:56:24
# 3580535  0DC9ABA632D33F46   docked_bike  2023-05-19 14:56:37
# 3580553  735D0B249DEC4E2F   docked_bike  2023-05-22 16:35:54
#
#                     ended_at     start_station_name start_station_id  \
# 13       2023-05-24 16:59:19        E 47 St & 1 Ave          6498.09
# 215      2023-05-15 19:16:28        W 25 St & 6 Ave          6215.04
# ...

# %% [markdown]
# ## Identity Research Questions

# %% [markdown]
# ### some random questions i want to know more about
# * how long is the average bike ride? what about classic vs. ebike? is one usually shorter than the other?
# * what the hell is a "docked_bike"? how is it different compared to "electric_bike" and "classic_bike"?
# * calculate the average MPH of bike rides. is there a difference between ebikes and regular bikes? do people take advantage of one over the other?
# * what is more popular? ebike or regular? is there a difference for members vs casual riders?
# * what percent of bike rides are casual (non-members)? where is the biggest revenue being generated? regular or ebike? members or casual?
# * given the curr costs for regular vs. ebike, which generates more revenue?
# * where are people biking to/from (QGIS)?
# * where are people picking up the most? where are people dropping off the most?
# * is there a difference in where Ebikes vs. regular bikes are picked up and dropped off? like is it more common to see ebikes in use in certain parts of NYC?
# * how many of the same people use the same type of bikes? is it more common to see a unique user use all ebikes vs all regular?
# * what is the most bike-ride-start heavy street/avenue? what about drop off?
# * are bikes being dropped off and picked up from the same stops at the same time? aka are people riding citibikes together??
# * is there a "most popular" station?
# * is there a "most popular route"? how does one even calculate this?

# %% [markdown]
# ## Clean and Prep Data

# %% [markdown]
# ## Analyze Data

# %% [markdown]
# ## Visualize and Communicate Data
